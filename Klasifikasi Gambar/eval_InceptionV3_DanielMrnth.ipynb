# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import random
import os

from tensorflow.keras.layers import Input, Dense, Flatten, GlobalAveragePooling2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from keras.layers import Dropout
from keras.models import Model
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
import zipfile
local_zip = './backup/dataset.zip'
zip_ref = zipfile.ZipFile(local_zip,'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
Lok = '/tmp/dataset/'

# %%
os.listdir('/tmp/dataset/')
# Out:
# ['test', 'train']

# %%
image_datagen =tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, 
                                                               rotation_range=20,
                                                              width_shift_range=0.2,
                                                              height_shift_range=0.2,
                                                              horizontal_flip=True,
                                                              validation_split=0.2)

# %%
train_ds = image_datagen.flow_from_directory(Lok+'/train',
                                            subset='training',
                                            target_size=(150, 150),
                                            batch_size=10)

val_ds   = image_datagen.flow_from_directory(Lok+'/train',
                                            subset='validation',
                                            target_size=(150, 150),
                                            batch_size=10)
# Out:
# Found 299 images belonging to 2 classes.
# Found 74 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import InceptionV3


ModelInceptionV3 = tf.keras.models.Sequential([
    tf.keras.applications.InceptionV3(input_shape=(150, 150, 3),
                                         include_top=False,
                                         pooling='max',
                                         weights='imagenet'),
    # tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.2),
#     tf.keras.layers.Dense(256, activation='ReLU'),
    tf.keras.layers.Dense(128, activation='ReLU'),
#    tf.keras.layers.Dense(64, activation='ReLU'),
#    tf.keras.layers.Dense(32, activation='ReLU'),
    tf.keras.layers.Dense(16, activation='ReLU'),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
ModelInceptionV3.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.0001,
                                                momentum=0.9
                                                 ), 
            loss='categorical_crossentropy',
            metrics = ['accuracy'])

ModelInceptionV3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2048)              21802784
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 16)                2064
#
#  dense_2 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 22,067,154
# Trainable params: 22,032,722
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
CegahUnderOrOver = EarlyStopping(monitor='val_accuracy',
                                patience=10,
                                min_delta=0.001,
                                mode='max',
                                restore_best_weights=True
                                )

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
reducelr = ReduceLROnPlateau(monitor='val_accuracy',
                            factor=0.3,
                            patience=8,
                            min_lr=0.001,
                            mode='auto',
                            verbose=1)

# %%
# %%time
train_InceptionV3 = ModelInceptionV3.fit(train_ds, validation_data=val_ds, epochs=12, callbacks=[CegahUnderOrOver, reducelr])
# Out:
# Epoch 1/12
# 30/30 [==============================] - 43s 1s/step - loss: 0.5951 - accuracy: 0.6856 - val_loss: 0.9638 - val_accuracy: 0.5676 - lr: 1.0000e-04
# Epoch 2/12
# 30/30 [==============================] - 32s 1s/step - loss: 0.3780 - accuracy: 0.8763 - val_loss: 0.3521 - val_accuracy: 0.7838 - lr: 1.0000e-04
# Epoch 3/12
# 30/30 [==============================] - 32s 1s/step - loss: 0.2455 - accuracy: 0.9164 - val_loss: 0.3107 - val_accuracy: 0.8378 - lr: 1.0000e-04
# Epoch 4/12
# 30/30 [==============================] - 32s 1s/step - loss: 0.1921 - accuracy: 0.9231 - val_loss: 0.2227 - val_accuracy: 0.9189 - lr: 1.0000e-04
# Epoch 5/12
# 30/30 [==============================] - 33s 1s/step - loss: 0.1576 - accuracy: 0.9498 - val_loss: 0.1436 - val_accuracy: 0.9324 - lr: 1.0000e-04
# Epoch 6/12
# 30/30 [==============================] - 33s 1s/step - loss: 0.1055 - accuracy: 0.9666 - val_loss: 0.0415 - val_accuracy: 0.9865 - lr: 1.0000e-04
# Epoch 7/12
# 30/30 [==============================] - 33s 1s/step - loss: 0.0927 - accuracy: 0.9732 - val_loss: 0.0879 - val_accuracy: 0.9324 - lr: 1.0000e-04
# Epoch 8/12
# 30/30 [==============================] - 34s 1s/step - loss: 0.1065 - accuracy: 0.9565 - val_loss: 0.0901 - val_accuracy: 0.9459 - lr: 1.0000e-04
# Epoch 9/12
# 30/30 [==============================] - 34s 1s/step - loss: 0.0618 - accuracy: 0.9833 - val_loss: 0.0417 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 10/12
# 30/30 [==============================] - 35s 1s/step - loss: 0.1097 - accuracy: 0.9699 - val_loss: 0.0440 - val_accuracy: 0.9865 - lr: 1.0000e-04
# Epoch 11/12
# 30/30 [==============================] - 35s 1s/step - loss: 0.0346 - accuracy: 0.9967 - val_loss: 0.1124 - val_accuracy: 0.9595 - lr: 1.0000e-04
# Epoch 12/12
# 30/30 [==============================] - 35s 1s/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Wall time: 6min 51s

# %%
plt.plot(train_InceptionV3.history['accuracy'])
plt.plot(train_InceptionV3.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(train_InceptionV3.history['loss'])
plt.plot(train_InceptionV3.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
ModelInceptionV3.evaluate(val_ds)

plt.plot(train_InceptionV3.history['accuracy'])
plt.plot(train_InceptionV3.history['val_accuracy'])
plt.title('Model InceptionV3 accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(train_InceptionV3.history['loss'])
plt.plot(train_InceptionV3.history['val_loss'])
plt.title('Model InceptionV3 loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# 8/8 [==============================] - 2s 197ms/step - loss: 0.0355 - accuracy: 0.9865

# %%
sub_csv ='./backup/Book12.csv'
path_test = './dataset/test/'

# %%
df_sub = pd.read_csv(sub_csv)
image_id = df_sub['ID']
df_sub.head(10)
# Out:
#                    ID  Label
# 0                36-0      0
# 1     20221104_081206      0
# 2     20221104_081209      0
# 3  Chicken-Whole-Leg2      0
# 4            IMG_4911      0
# 5            IMG_4912      0
# 6            IMG_4913      0
# 7            IMG_4914      0
# 8            IMG_4915      0
# 9            IMG_4916      0

# %%
# Masing-masing gambar akan diperlakukan secara individual dan disimpan dalam daftar yang kemudian bergabung dengan ID file tersebut

from tensorflow.keras.preprocessing.image import load_img


# membuat daftar yg diprediksi
labels = []


for i in image_id:
    image = load_img('./backup/dataset/test/'+str(i)+'.jpg', target_size=(150, 150))
    img = np.array(image)
    img = img / 255.0
    img = img.reshape(1,150,150,3)
    label = ModelInceptionV3.predict(img)
    label_id = label[0].tolist()
    
    labels.append(label_id.index(max(label_id)))
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 56ms/step

# %%
df_sub['Label'] = labels
df_sub.head(10)
# Out:
#                    ID  Label
# 0                36-0      1
# 1     20221104_081206      0
# 2     20221104_081209      0
# 3  Chicken-Whole-Leg2      1
# 4            IMG_4911      1
# 5            IMG_4912      1
# 6            IMG_4913      1
# 7            IMG_4914      1
# 8            IMG_4915      1
# 9            IMG_4916      1

# %%
df_prediksi_test = pd.DataFrame({'image_name':image_id,
                                 'prediksi':labels})

# %%
df_prediksi_test
# Out:
#             image_name  prediksi
# 0                 36-0         1
# 1      20221104_081206         0
# 2      20221104_081209         0
# 3   Chicken-Whole-Leg2         1
# 4             IMG_4911         1
# 5             IMG_4912         1
# 6             IMG_4913         1
# 7             IMG_4914         1
# 8             IMG_4915         1
# 9             IMG_4916         1
# 10            IMG_5113         1
# 11            IMG_5114         1
# 12            IMG_5115         1
# 13            IMG_5116         1
# 14            IMG_5117         1
# 15            IMG_5118         1
# 16            IMG_5247         0
# 17            IMG_5248         0
# 18            IMG_5249         0

# %%
df_prediksi_test.replace(to_replace=[0, 1], value=["AyamSegar", "AyamTiren"], inplace=True)

# %%
df_prediksi_test
# Out:
#             image_name   prediksi
# 0                 36-0  AyamTiren
# 1      20221104_081206  AyamSegar
# 2      20221104_081209  AyamSegar
# 3   Chicken-Whole-Leg2  AyamTiren
# 4             IMG_4911  AyamTiren
# 5             IMG_4912  AyamTiren
# 6             IMG_4913  AyamTiren
# 7             IMG_4914  AyamTiren
# 8             IMG_4915  AyamTiren
# 9             IMG_4916  AyamTiren
# 10            IMG_5113  AyamTiren
# 11            IMG_5114  AyamTiren
# 12            IMG_5115  AyamTiren
# 13            IMG_5116  AyamTiren
# 14            IMG_5117  AyamTiren
# 15            IMG_5118  AyamTiren
# 16            IMG_5247  AyamSegar
# 17            IMG_5248  AyamSegar
# 18            IMG_5249  AyamSegar

# %%
df_prediksi_test.to_csv("DataPrediksiTest2_InceptionV3.csv", index=False)

# %%
ds_aktual = pd.read_csv("./DataTest.csv")
ds_predict = pd.read_csv("./DataPrediksiTest2_InceptionV3.csv")

# %%
ds_aktual.rename(columns={'prediksi':'label'}, inplace=True)

# %%
ds_aktual
# Out:
#             image_name      label
# 0                 36-0  AyamTiren
# 1      20221104_081206  AyamSegar
# 2      20221104_081209  AyamSegar
# 3   Chicken-Whole-Leg2  AyamSegar
# 4             IMG_4911  AyamTiren
# 5             IMG_4912  AyamTiren
# 6             IMG_4913  AyamTiren
# 7             IMG_4914  AyamTiren
# 8             IMG_4915  AyamTiren
# 9             IMG_4916  AyamTiren
# 10            IMG_5113  AyamTiren
# 11            IMG_5114  AyamTiren
# 12            IMG_5115  AyamTiren
# 13            IMG_5116  AyamTiren
# 14            IMG_5117  AyamTiren
# 15            IMG_5118  AyamTiren
# 16            IMG_5247  AyamSegar
# 17            IMG_5248  AyamSegar
# 18            IMG_5249  AyamSegar

# %%
df_test_eval = pd.merge(
    ds_predict,
    ds_aktual,
    how="inner",
    on='image_name')

# %%
df_test_eval
# Out:
#             image_name   prediksi      label
# 0                 36-0  AyamTiren  AyamTiren
# 1      20221104_081206  AyamSegar  AyamSegar
# 2      20221104_081209  AyamSegar  AyamSegar
# 3   Chicken-Whole-Leg2  AyamTiren  AyamSegar
# 4             IMG_4911  AyamTiren  AyamTiren
# 5             IMG_4912  AyamTiren  AyamTiren
# 6             IMG_4913  AyamTiren  AyamTiren
# 7             IMG_4914  AyamTiren  AyamTiren
# 8             IMG_4915  AyamTiren  AyamTiren
# 9             IMG_4916  AyamTiren  AyamTiren
# 10            IMG_5113  AyamTiren  AyamTiren
# 11            IMG_5114  AyamTiren  AyamTiren
# 12            IMG_5115  AyamTiren  AyamTiren
# 13            IMG_5116  AyamTiren  AyamTiren
# 14            IMG_5117  AyamTiren  AyamTiren
# 15            IMG_5118  AyamTiren  AyamTiren
# 16            IMG_5247  AyamSegar  AyamSegar
# 17            IMG_5248  AyamSegar  AyamSegar
# 18            IMG_5249  AyamSegar  AyamSegar

# %% [markdown]
# ## Confusion Confusion matrik data test

# %%
from sklearn.metrics import confusion_matrix
y_actual = df_test_eval['label']
y_pred = df_test_eval['prediksi']
confusion_matrix(y_actual, y_pred)
# Out:
# array([[ 5,  1],
#        [ 0, 13]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_actual, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#    AyamSegar       1.00      0.83      0.91         6
#    AyamTiren       0.93      1.00      0.96        13
#
#     accuracy                           0.95        19
#    macro avg       0.96      0.92      0.94        19
# weighted avg       0.95      0.95      0.95        19

# %% [markdown]
# ## Evaluasi data train

# %%
sub_csv ='./backup/dataTrain.csv'
path_test = './backup/dataset-real/dataset/train/'

# %%
df_sub_train = pd.read_csv(sub_csv)
image_id = df_sub_train['image_name']
df_sub_train.head(10)
# Out:
#         image_name      label
# 0  20221104_081212  AyamSegar
# 1  20221104_081215  AyamSegar
# 2  20221104_081217  AyamSegar
# 3  20221104_081220  AyamSegar
# 4  20221104_081222  AyamSegar
# 5  20221104_081226  AyamSegar
# 6  20221104_081228  AyamSegar
# 7  20221104_081233  AyamSegar
# 8  20221104_081237  AyamSegar
# 9  20221104_081241  AyamSegar

# %%
# Masing-masing gambar akan diperlakukan secara individual dan disimpan dalam daftar yang kemudian bergabung dengan ID file tersebut

from tensorflow.keras.preprocessing.image import load_img


# membuat daftar yg diprediksi
labels = []


for i in image_id:
    image = load_img('./backup/dataset-real/dataset/train/'+str(i)+'.jpg', target_size=(150, 150))
    img = np.array(image)
    img = img / 255.0
    img = img.reshape(1,150,150,3)
    label = ModelInceptionV3.predict(img)
    label_id = label[0].tolist()
    
    labels.append(label_id.index(max(label_id)))
# Out:
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 71ms/step

# %%
df_sub_train['Label'] = labels
df_sub_train.head(10)
# Out:
#         image_name      label  Label
# 0  20221104_081212  AyamSegar      0
# 1  20221104_081215  AyamSegar      0
# 2  20221104_081217  AyamSegar      0
# 3  20221104_081220  AyamSegar      0
# 4  20221104_081222  AyamSegar      0
# 5  20221104_081226  AyamSegar      0
# 6  20221104_081228  AyamSegar      0
# 7  20221104_081233  AyamSegar      0
# 8  20221104_081237  AyamSegar      0
# 9  20221104_081241  AyamSegar      0

# %%
df_prediksi_train = pd.DataFrame({'image_name':image_id,
                                 'prediksi':labels})

# %%
df_prediksi_train
# Out:
#           image_name  prediksi
# 0    20221104_081212         0
# 1    20221104_081215         0
# 2    20221104_081217         0
# 3    20221104_081220         0
# 4    20221104_081222         0
# ..               ...       ...
# 368         IMG_5121         1
# 369         IMG_5122         1
# 370         IMG_5123         1
# 371         IMG_5124         1
# 372         IMG_5125         1
#
# [373 rows x 2 columns]

# %%
df_prediksi_train.replace(to_replace=[0, 1], value=["AyamSegar", "AyamTiren"], inplace=True)

# %%
df_prediksi_train.to_csv("DataPrediksiTrainValid.csv", index=False)

# %%
ds_aktual_train = pd.read_csv("./backup/dataTrain.csv")
ds_predict_train = pd.read_csv("./DataPrediksiTrainValid.csv")

# %%
ds_aktual_train
# Out:
#           image_name      label
# 0    20221104_081212  AyamSegar
# 1    20221104_081215  AyamSegar
# 2    20221104_081217  AyamSegar
# 3    20221104_081220  AyamSegar
# 4    20221104_081222  AyamSegar
# ..               ...        ...
# 368         IMG_5121  AyamTiren
# 369         IMG_5122  AyamTiren
# 370         IMG_5123  AyamTiren
# 371         IMG_5124  AyamTiren
# 372         IMG_5125  AyamTiren
#
# [373 rows x 2 columns]

# %%
df_train_eval = pd.merge(
    ds_aktual_train,
    ds_predict_train,
    how="inner",
    on='image_name')

# %%
df_train_eval
# Out:
#           image_name      label   prediksi
# 0    20221104_081212  AyamSegar  AyamSegar
# 1    20221104_081215  AyamSegar  AyamSegar
# 2    20221104_081217  AyamSegar  AyamSegar
# 3    20221104_081220  AyamSegar  AyamSegar
# 4    20221104_081222  AyamSegar  AyamSegar
# ..               ...        ...        ...
# 368         IMG_5121  AyamTiren  AyamTiren
# 369         IMG_5122  AyamTiren  AyamTiren
# 370         IMG_5123  AyamTiren  AyamTiren
# 371         IMG_5124  AyamTiren  AyamTiren
# 372         IMG_5125  AyamTiren  AyamTiren
#
# [373 rows x 3 columns]

# %% [markdown]
# ## Confusion matrik

# %%
from sklearn.metrics import confusion_matrix
y_actual = df_train_eval['label']
y_pred = df_train_eval['prediksi']
confusion_matrix(y_actual, y_pred)
# Out:
# array([[172,   1],
#        [  0, 200]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_actual, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#    AyamSegar       1.00      0.99      1.00       173
#    AyamTiren       1.00      1.00      1.00       200
#
#     accuracy                           1.00       373
#    macro avg       1.00      1.00      1.00       373
# weighted avg       1.00      1.00      1.00       373

# %%
pwd
# Out:
# 'C:\\Users\\ASUS\\LatihanPython_DanielMorantha\\Orbit\\Practical\\Proyek Akhir\\DanielMrnth-KodeNModel'
