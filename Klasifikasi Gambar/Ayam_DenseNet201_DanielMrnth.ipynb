# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import random
import os

from tensorflow.keras.layers import Input, Dense, Flatten, GlobalAveragePooling2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from keras.layers import Dropout
from keras.models import Model
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# -illow                             8.2.0
# -pencv-contrib-python              4.5.4.60
# -tatsmodels                        0.12.2
# absl-py                            1.1.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# awscli                             1.25.12
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# blur-image                         0.1.0
# bokeh                              2.3.2
# boto                               2.49.0
# boto3                              1.24.12
# botocore                           1.27.12
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cachetools                         5.2.0
# catboost                           1.1.1
# certifi                            2021.5.30
# cffi                               1.14.5
# chardet                            4.0.0
# charset-normalizer                 2.0.12
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# colorcet                           2.0.6
# commonmark                         0.9.1
# comtypes                           1.1.9
# conda                              4.11.0
# conda-build                        3.21.4
# conda-content-trust                0+unknown
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# contourpy                          1.0.5
# cryptography                       3.4.7
# cuda-python                        11.7.0
# cycler                             0.10.0
# Cython                             0.29.28
# cytoolz                            0.11.0
# dask                               2021.4.0
# decorator                          5.0.6
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# dill                               0.3.6
# distributed                        2021.4.0
# docker                             5.0.3
# docopt                             0.6.2
# docutils                           0.16
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# etils                              0.9.0
# fastcache                          1.1.0
# feature-engine                     1.1.2
# filelock                           3.0.12
# flake8                             3.9.0
# Flask                              1.1.2
# flatbuffers                        2.0.7
# fonttools                          4.37.3
# fsspec                             0.9.0
# future                             0.18.2
# gast                               0.4.0
# gensim                             4.2.0
# gevent                             21.1.2
# glob2                              0.7
# google-auth                        2.8.0
# google-auth-oauthlib               0.4.6
# google-pasta                       0.2.0
# googleapis-common-protos           1.56.4
# graphviz                           0.19.1
# grayscale-image                    0.1.0
# greenlet                           1.0.0
# grpcio                             1.46.3
# gunicorn                           20.1.0
# gym                                0.26.2
# gym-notices                        0.0.8
# h5py                               2.10.0
# HeapDict                           1.0.1
# holoviews                          1.14.6
# html5lib                           1.1
# huggingface                        0.0.1
# huggingface-hub                    0.8.1
# hyperopt                           0.2.7
# idna                               2.10
# imageai                            2.1.5
# imagecodecs                        2021.3.31
# imageio                            2.9.0
# imagesize                          1.2.0
# imbalanced-learn                   0.9.1
# imgviz                             1.5.1
# importlib-metadata                 5.0.0
# importlib-resources                5.10.0
# iniconfig                          1.1.1
# intel-openmp                       2022.1.0
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.8.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# jmespath                           1.0.1
# joblib                             1.0.1
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.4.0
# jupyterlab-widgets                 1.0.0
# keras                              2.9.0
# Keras-Preprocessing                1.1.2
# keras-resnet                       0.2.0
# keras-vgg-buddy                    0.1.1
# keyring                            8.7
# keyrings.alt                       4.1.0
# kiwisolver                         1.3.1
# labelImg                           1.8.6
# labelme                            5.0.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# libclang                           14.0.1
# llvmlite                           0.36.0
# locket                             0.2.1
# lxml                               4.9.1
# Mako                               1.2.3
# Markdown                           3.3.4
# MarkupSafe                         1.1.1
# matplotlib                         3.2.2
# maze                               3.0.0
# mccabe                             0.6.1
# mediapipe                          0.8.10
# menuinst                           1.4.16
# MiniSom                            2.3.0
# missingno                          0.5.0
# mistune                            0.8.4
# mkl                                2022.1.0
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mlxtend                            0.19.0
# mock                               4.0.3
# more-itertools                     8.7.0
# mplot3d-dragger                    0.0.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# mypy-extensions                    0.4.3
# mysql-connector                    2.2.9
# mysql-connector-python             8.0.28
# natsort                            8.2.0
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.0.7
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.5
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           6.3.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.23.4
# numpydoc                           1.1.0
# nvidia-pyindex                     1.0.9
# oauthlib                           3.2.0
# olefile                            0.46
# opencv-python                      4.1.2.30
# opencv-python-headless             4.6.0.66
# openpyxl                           3.0.7
# opt-einsum                         3.3.0
# packaging                          21.3
# pandas                             1.2.4
# pandocfilters                      1.4.3
# panel                              0.12.1
# param                              1.12.0
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# patsy                              0.5.2
# pep8                               1.7.1
# pexpect                            4.8.0
# pickle-mixin                       1.0.2
# pickleshare                        0.7.5
# Pillow                             8.4.0
# pip                                21.0.1
# pkginfo                            1.8.3
# plotly                             5.11.0
# pluggy                             0.13.1
# ply                                3.11
# pmdarima                           2.0.1
# prometheus-client                  0.10.1
# promise                            2.3
# prompt-toolkit                     3.0.17
# protobuf                           3.19.4
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# py4j                               0.10.9.3
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pybind11                           2.10.0
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pyct                               0.4.8
# pycurl                             7.43.0.6
# pydocstyle                         6.0.0
# pyerfa                             1.7.3
# pyflakes                           2.2.0
# pyglet                             1.5.27
# Pygments                           2.8.1
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# PyQt5                              5.15.7
# PyQt5-Qt5                          5.15.2
# PyQt5-sip                          12.11.0
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             6.2.3
# python-dateutil                    2.8.1
# python-dotenv                      0.21.0
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# python-resize-image                1.1.20
# python-utils                       3.3.3
# pytz                               2021.1
# pyviz-comms                        2.0.2
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.0.3
# QtPy                               1.9.0
# readme-renderer                    35.0
# regex                              2021.4.4
# rendering                          0.0.0
# reportlab                          3.6.11
# requests                           2.28.0
# requests-oauthlib                  1.3.1
# requests-toolbelt                  0.9.1
# rfc3986                            2.0.0
# rich                               12.4.4
# roboflow                           0.2.20
# rope                               0.18.0
# rsa                                4.7.2
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# ruamel.yaml                        0.17.21
# ruamel.yaml.clib                   0.2.6
# s3transfer                         0.6.0
# Sastrawi                           1.0.1
# scikit-image                       0.18.1
# scikit-learn                       1.1.1
# scipy                              1.6.2
# seaborn                            0.11.1
# sed                                0.3.1
# Send2Trash                         1.5.0
# setuptools                         52.0.0.post20210125
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# sip                                4.19.13
# six                                1.15.0
# smart-open                         6.2.0
# smote-variants                     0.4.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.2.1
# Sphinx                             4.0.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.7
# statistics                         1.0.3.5
# statsmodels                        0.13.2
# sympy                              1.8
# tables                             3.6.1
# tabulate                           0.8.9
# tbb                                2021.6.0
# tblib                              1.7.0
# tenacity                           8.1.0
# tensorboard                        2.9.1
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.8.1
# tensorflow                         2.9.1
# tensorflow-datasets                4.7.0
# tensorflow-estimator               2.9.0
# tensorflow-gpu                     2.10.0
# tensorflow-hub                     0.12.0
# tensorflow-io                      0.26.0
# tensorflow-io-gcs-filesystem       0.26.0
# tensorflow-metadata                1.10.0
# tensorflow-object-detection-api    0.1.1
# tensorflowjs                       3.18.0
# termcolor                          1.1.0
# terminado                          0.9.4
# testpath                           0.4.4
# textdistance                       4.2.1
# tf-bodypix                         0.4.0
# tfjs-graph-converter               1.6.0
# thop                               0.1.1.post2209072238
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2021.4.8
# tokenizers                         0.12.1
# toml                               0.10.2
# toolz                              0.11.1
# torch                              1.12.0+cu116
# torchaudio                         0.12.0+cu116
# torchvision                        0.13.0+cu116
# tornado                            6.1
# tqdm                               4.64.1
# traitlets                          5.0.5
# transformers                       4.20.1
# twine                              4.0.1
# typed-ast                          1.4.2
# typing-extensions                  4.2.0
# ujson                              4.0.2
# unicodecsv                         0.14.1
# urllib3                            1.26.6
# voluptuous                         0.13.1
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# websocket-client                   1.3.2
# Werkzeug                           1.0.1
# wget                               3.2
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wordcloud                          1.8.2.2
# wrapt                              1.12.1
# xgboost                            1.5.1
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# yolo                               0.3.1
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.3.0

# %%
import zipfile
local_zip = './backup/dataset.zip'
zip_ref = zipfile.ZipFile(local_zip,'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
Lok = '/tmp/dataset/'

# %%
os.listdir('/tmp/dataset/')
# Out:
# ['test', 'train']

# %% [markdown]
# # 2. Image Acquistion

# %%
kelas = []
n_gmbar = []
data = {'KualitasDaging':[], 'JumlahFoto':[]}

for i in os.listdir(Lok+'/train'):
    n_gmbar.append(len(os.listdir(Lok+'/train/'+i)))
    kelas.append(i)
    
data['KualitasDaging']+=kelas
data['JumlahFoto']+=n_gmbar

df = pd.DataFrame(data)
df
# Out:
#   KualitasDaging  JumlahFoto
# 0      AyamSegar         173
# 1      AyamTiren         200

# %%
sns.barplot(x=df['KualitasDaging'], y=df['JumlahFoto'])

# %%
KualitasDaging = os.listdir(Lok+'/train')

plt.figure(figsize=(30,30))
for x in range(10):
    i       = random.randint(0,1)  #mengambbil gambar dari 3 folder
    NamaKls = os.listdir(Lok+'/train'+'/'+KualitasDaging[i])
    
    j          = random.randint(0,100)
    gmbr       = cv2.imread(Lok+'/train'+'/'+KualitasDaging[i]+'/'+NamaKls[j])
    gmbr       = cv2.cvtColor(gmbr, cv2.COLOR_BGR2RGB)
    ax         = plt.subplot(5, 5, x+1)
    plt.imshow(gmbr)
    plt.title(KualitasDaging[i])
    plt.axis("off")
    
plt.show()

# %% [markdown]
# # 3. Pre-processing

# %%
image_datagen =tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, 
                                                               rotation_range=20,
                                                              width_shift_range=0.2,
                                                              height_shift_range=0.2,
                                                              horizontal_flip=True,
                                                              validation_split=0.2)

# %%
train_ds = image_datagen.flow_from_directory(Lok+'/train',
                                            subset='training',
                                            target_size=(150, 150),
                                            batch_size=10)

val_ds   = image_datagen.flow_from_directory(Lok+'/train',
                                            subset='validation',
                                            target_size=(150, 150),
                                            batch_size=10)
# Out:
# Found 299 images belonging to 2 classes.
# Found 74 images belonging to 2 classes.

# %% [markdown]
# # 4. Modeling

# %% [markdown]
# ## 4.1Model DenseNet201

# %%
ModelDenseNet201 = tf.keras.models.Sequential([
    tf.keras.applications.DenseNet201(input_shape=(150, 150, 3),
                                         include_top=False,
                                         pooling='max',
                                         weights='imagenet'),
    # tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='ReLU'),
    tf.keras.layers.Dense(128, activation='ReLU'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='ReLU'),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
ModelDenseNet201.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.0005,
                                                momentum=0.9
                                                 ), 
            loss='categorical_crossentropy',
            metrics = ['accuracy'])

ModelDenseNet201.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  flatten (Flatten)           (None, 1920)              0
#
#  dropout (Dropout)           (None, 1920)              0
#
#  dense (Dense)               (None, 256)               491776
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 18,855,042
# Trainable params: 18,625,986
# Non-trainable params: 229,056
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
CegahUnderOrOver = EarlyStopping(monitor='val_accuracy',
                                patience=10,
                                min_delta=0.001,
                                mode='max',
                                restore_best_weights=True
                                )

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
reducelr = ReduceLROnPlateau(monitor='val_accuracy',
                            factor=0.3,
                            patience=8,
                            min_lr=0.001,
                            mode='auto',
                            verbose=1)

# %%
# %%time
train_DenseNet201 = ModelDenseNet201.fit(train_ds, validation_data=val_ds, epochs=12, callbacks=[CegahUnderOrOver, reducelr])
# Out:
# Epoch 1/12
# 30/30 [==============================] - 105s 3s/step - loss: 0.4691 - accuracy: 0.7759 - val_loss: 0.1201 - val_accuracy: 0.9865 - lr: 5.0000e-04
# Epoch 2/12
# 30/30 [==============================] - 80s 3s/step - loss: 0.0625 - accuracy: 0.9799 - val_loss: 0.0205 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 3/12
# 30/30 [==============================] - 79s 3s/step - loss: 0.0448 - accuracy: 0.9799 - val_loss: 0.0248 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 4/12
# 30/30 [==============================] - 91s 3s/step - loss: 0.0214 - accuracy: 0.9967 - val_loss: 0.0177 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 5/12
# 30/30 [==============================] - 100s 3s/step - loss: 0.0296 - accuracy: 0.9900 - val_loss: 0.0045 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 6/12
# 30/30 [==============================] - 86s 3s/step - loss: 0.0137 - accuracy: 0.9967 - val_loss: 0.0056 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 7/12
# 30/30 [==============================] - 86s 3s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 8/12
# 30/30 [==============================] - 80s 3s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 5.3641e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 9/12
# 30/30 [==============================] - 80s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 8.2295e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 10/12
# 30/30 [==============================] - 85s 3s/step - loss: 0.0368 - accuracy: 0.9833 - val_loss: 3.2203e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 11/12
# 30/30 [==============================] - 83s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.7544e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 12/12
# 30/30 [==============================] - 86s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.8454e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Wall time: 17min 22s

# %% [markdown]
# # 5. Evaluasi Model

# %%
ModelDenseNet201.evaluate(val_ds)

plt.plot(train_DenseNet201.history['accuracy'])
plt.plot(train_DenseNet201.history['val_accuracy'])
plt.title('Model DenseNet201 accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(train_DenseNet201.history['loss'])
plt.plot(train_DenseNet201.history['val_loss'])
plt.title('Model DenseNet201 loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# 8/8 [==============================] - 6s 571ms/step - loss: 0.0212 - accuracy: 1.0000

# %% [markdown]
# # Evaluasi data test dg Confusion matrik

# %%
sub_csv ='./backup/Book12.csv'
path_test = './dataset/test/'

# %%
df_sub = pd.read_csv(sub_csv)
image_id = df_sub['ID']
df_sub.head(10)
# Out:
#                    ID  Label
# 0                36-0      0
# 1     20221104_081206      0
# 2     20221104_081209      0
# 3  Chicken-Whole-Leg2      0
# 4            IMG_4911      0
# 5            IMG_4912      0
# 6            IMG_4913      0
# 7            IMG_4914      0
# 8            IMG_4915      0
# 9            IMG_4916      0

# %%
# Masing-masing gambar akan diperlakukan secara individual dan disimpan dalam daftar yang kemudian bergabung dengan ID file tersebut

from tensorflow.keras.preprocessing.image import load_img


# membuat daftar yg diprediksi
labels = []


for i in image_id:
    image = load_img('./backup/dataset/test/'+str(i)+'.jpg', target_size=(150, 150))
    img = np.array(image)
    img = img / 255.0
    img = img.reshape(1,150,150,3)
    label = ModelDenseNet201.predict(img)
    label_id = label[0].tolist()
    
    labels.append(label_id.index(max(label_id)))
# Out:
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 972ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 993ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 991ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step

# %%
df_sub['Label'] = labels
df_sub.head(10)
# Out:
#                    ID  Label
# 0                36-0      1
# 1     20221104_081206      0
# 2     20221104_081209      0
# 3  Chicken-Whole-Leg2      0
# 4            IMG_4911      1
# 5            IMG_4912      1
# 6            IMG_4913      1
# 7            IMG_4914      1
# 8            IMG_4915      1
# 9            IMG_4916      1

# %%
df_prediksi_test = pd.DataFrame({'image_name':image_id,
                                 'prediksi':labels})

# %%
df_prediksi_test
# Out:
#             image_name  prediksi
# 0                 36-0         1
# 1      20221104_081206         0
# 2      20221104_081209         0
# 3   Chicken-Whole-Leg2         0
# 4             IMG_4911         1
# 5             IMG_4912         1
# 6             IMG_4913         1
# 7             IMG_4914         1
# 8             IMG_4915         1
# 9             IMG_4916         1
# 10            IMG_5113         1
# 11            IMG_5114         1
# 12            IMG_5115         1
# 13            IMG_5116         1
# 14            IMG_5117         1
# 15            IMG_5118         1
# 16            IMG_5247         0
# 17            IMG_5248         0
# 18            IMG_5249         0

# %%
df_prediksi_test.replace(to_replace=[0, 1], value=["AyamSegar", "AyamTiren"], inplace=True)

# %%
df_prediksi_test
# Out:
#             image_name   prediksi
# 0                 36-0  AyamTiren
# 1      20221104_081206  AyamSegar
# 2      20221104_081209  AyamSegar
# 3   Chicken-Whole-Leg2  AyamSegar
# 4             IMG_4911  AyamTiren
# 5             IMG_4912  AyamTiren
# 6             IMG_4913  AyamTiren
# 7             IMG_4914  AyamTiren
# 8             IMG_4915  AyamTiren
# 9             IMG_4916  AyamTiren
# 10            IMG_5113  AyamTiren
# 11            IMG_5114  AyamTiren
# 12            IMG_5115  AyamTiren
# 13            IMG_5116  AyamTiren
# 14            IMG_5117  AyamTiren
# 15            IMG_5118  AyamTiren
# 16            IMG_5247  AyamSegar
# 17            IMG_5248  AyamSegar
# 18            IMG_5249  AyamSegar

# %%
df_prediksi_test.to_csv("DataPrediksiTest_DenseNet201.csv", index=False)

# %%
ds_aktual = pd.read_csv("./DataTest.csv")
ds_predict = pd.read_csv("./DataPrediksiTest_DenseNet201.csv")

# %%
ds_aktual.rename(columns={'prediksi':'label'}, inplace=True)

# %%
ds_aktual
# Out:
#             image_name      label
# 0                 36-0  AyamTiren
# 1      20221104_081206  AyamSegar
# 2      20221104_081209  AyamSegar
# 3   Chicken-Whole-Leg2  AyamSegar
# 4             IMG_4911  AyamTiren
# 5             IMG_4912  AyamTiren
# 6             IMG_4913  AyamTiren
# 7             IMG_4914  AyamTiren
# 8             IMG_4915  AyamTiren
# 9             IMG_4916  AyamTiren
# 10            IMG_5113  AyamTiren
# 11            IMG_5114  AyamTiren
# 12            IMG_5115  AyamTiren
# 13            IMG_5116  AyamTiren
# 14            IMG_5117  AyamTiren
# 15            IMG_5118  AyamTiren
# 16            IMG_5247  AyamSegar
# 17            IMG_5248  AyamSegar
# 18            IMG_5249  AyamSegar

# %%
df_test_eval = pd.merge(
    ds_predict,
    ds_aktual,
    how="inner",
    on='image_name')

# %%
df_test_eval
# Out:
#             image_name   prediksi      label
# 0                 36-0  AyamTiren  AyamTiren
# 1      20221104_081206  AyamSegar  AyamSegar
# 2      20221104_081209  AyamSegar  AyamSegar
# 3   Chicken-Whole-Leg2  AyamSegar  AyamSegar
# 4             IMG_4911  AyamTiren  AyamTiren
# 5             IMG_4912  AyamTiren  AyamTiren
# 6             IMG_4913  AyamTiren  AyamTiren
# 7             IMG_4914  AyamTiren  AyamTiren
# 8             IMG_4915  AyamTiren  AyamTiren
# 9             IMG_4916  AyamTiren  AyamTiren
# 10            IMG_5113  AyamTiren  AyamTiren
# 11            IMG_5114  AyamTiren  AyamTiren
# 12            IMG_5115  AyamTiren  AyamTiren
# 13            IMG_5116  AyamTiren  AyamTiren
# 14            IMG_5117  AyamTiren  AyamTiren
# 15            IMG_5118  AyamTiren  AyamTiren
# 16            IMG_5247  AyamSegar  AyamSegar
# 17            IMG_5248  AyamSegar  AyamSegar
# 18            IMG_5249  AyamSegar  AyamSegar

# %% [markdown]
# ## confusion matrik data test

# %%
from sklearn.metrics import confusion_matrix
y_actual = df_test_eval['label']
y_pred = df_test_eval['prediksi']
confusion_matrix(y_actual, y_pred)
# Out:
# array([[ 6,  0],
#        [ 0, 13]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_actual, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#    AyamSegar       1.00      1.00      1.00         6
#    AyamTiren       1.00      1.00      1.00        13
#
#     accuracy                           1.00        19
#    macro avg       1.00      1.00      1.00        19
# weighted avg       1.00      1.00      1.00        19

# %% [markdown]
# # Evaluasi data train

# %%
sub_csv ='./backup/dataTrain.csv'
path_test = './backup/dataset-real/dataset/train/'

# %%
df_sub_train = pd.read_csv(sub_csv)
image_id = df_sub_train['image_name']
df_sub_train.head(10)
# Out:
#         image_name      label
# 0  20221104_081212  AyamSegar
# 1  20221104_081215  AyamSegar
# 2  20221104_081217  AyamSegar
# 3  20221104_081220  AyamSegar
# 4  20221104_081222  AyamSegar
# 5  20221104_081226  AyamSegar
# 6  20221104_081228  AyamSegar
# 7  20221104_081233  AyamSegar
# 8  20221104_081237  AyamSegar
# 9  20221104_081241  AyamSegar

# %%
# Masing-masing gambar akan diperlakukan secara individual dan disimpan dalam daftar yang kemudian bergabung dengan ID file tersebut

from tensorflow.keras.preprocessing.image import load_img


# membuat daftar yg diprediksi
labels = []


for i in image_id:
    image = load_img('./backup/dataset-real/dataset/train/'+str(i)+'.jpg', target_size=(150, 150))
    img = np.array(image)
    img = img / 255.0
    img = img.reshape(1,150,150,3)
    label = ModelDenseNet201.predict(img)
    label_id = label[0].tolist()
    
    labels.append(label_id.index(max(label_id)))
# Out:
# 1/1 [==============================] - 1s 900ms/step
# 1/1 [==============================] - 1s 919ms/step
# 1/1 [==============================] - 1s 924ms/step
# 1/1 [==============================] - 1s 929ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 95ms/step

# %%
df_sub_train['Label'] = labels
df_sub_train.head(10)
# Out:
#         image_name      label  Label
# 0  20221104_081212  AyamSegar      0
# 1  20221104_081215  AyamSegar      0
# 2  20221104_081217  AyamSegar      0
# 3  20221104_081220  AyamSegar      0
# 4  20221104_081222  AyamSegar      0
# 5  20221104_081226  AyamSegar      0
# 6  20221104_081228  AyamSegar      0
# 7  20221104_081233  AyamSegar      0
# 8  20221104_081237  AyamSegar      0
# 9  20221104_081241  AyamSegar      0

# %%
df_prediksi_train = pd.DataFrame({'image_name':image_id,
                                 'prediksi':labels})

# %%
df_prediksi_train
# Out:
#           image_name  prediksi
# 0    20221104_081212         0
# 1    20221104_081215         0
# 2    20221104_081217         0
# 3    20221104_081220         0
# 4    20221104_081222         0
# ..               ...       ...
# 368         IMG_5121         1
# 369         IMG_5122         1
# 370         IMG_5123         1
# 371         IMG_5124         1
# 372         IMG_5125         1
#
# [373 rows x 2 columns]

# %%
df_prediksi_train.replace(to_replace=[0, 1], value=["AyamSegar", "AyamTiren"], inplace=True)

# %%
df_prediksi_train.to_csv("DataPrediksiTrain-DenseNet201.csv", index=False)

# %%
ds_aktual_train = pd.read_csv("./backup/dataTrain.csv")
ds_predict_train = pd.read_csv("./DataPrediksiTrain-DenseNet201.csv")

# %%
ds_aktual_train
# Out:
#           image_name      label
# 0    20221104_081212  AyamSegar
# 1    20221104_081215  AyamSegar
# 2    20221104_081217  AyamSegar
# 3    20221104_081220  AyamSegar
# 4    20221104_081222  AyamSegar
# ..               ...        ...
# 368         IMG_5121  AyamTiren
# 369         IMG_5122  AyamTiren
# 370         IMG_5123  AyamTiren
# 371         IMG_5124  AyamTiren
# 372         IMG_5125  AyamTiren
#
# [373 rows x 2 columns]

# %%
df_train_eval = pd.merge(
    ds_aktual_train,
    ds_predict_train,
    how="inner",
    on='image_name')

# %%
df_train_eval
# Out:
#           image_name      label   prediksi
# 0    20221104_081212  AyamSegar  AyamSegar
# 1    20221104_081215  AyamSegar  AyamSegar
# 2    20221104_081217  AyamSegar  AyamSegar
# 3    20221104_081220  AyamSegar  AyamSegar
# 4    20221104_081222  AyamSegar  AyamSegar
# ..               ...        ...        ...
# 368         IMG_5121  AyamTiren  AyamTiren
# 369         IMG_5122  AyamTiren  AyamTiren
# 370         IMG_5123  AyamTiren  AyamTiren
# 371         IMG_5124  AyamTiren  AyamTiren
# 372         IMG_5125  AyamTiren  AyamTiren
#
# [373 rows x 3 columns]

# %% [markdown]
# ## Confusion matrik data train

# %%
from sklearn.metrics import confusion_matrix
y_actual = df_train_eval['label']
y_pred = df_train_eval['prediksi']
confusion_matrix(y_actual, y_pred)
# Out:
# array([[173,   0],
#        [  0, 200]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_actual, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#    AyamSegar       1.00      1.00      1.00       173
#    AyamTiren       1.00      1.00      1.00       200
#
#     accuracy                           1.00       373
#    macro avg       1.00      1.00      1.00       373
# weighted avg       1.00      1.00      1.00       373

# %%
pwd
# Out:
# 'C:\\Users\\ASUS\\LatihanPython_DanielMorantha\\Orbit\\Practical\\Proyek Akhir\\DanielMrnth-KodeNModel'

# %% [markdown]
# **Simpan Model**

# %%
ModelDenseNet201.save("AyamDenseNet201-DanielMrnth.h5")
# ModelVGG16.save("Ayam-VGG16-DanielMrnth.h5")
# ModelInceptionV3.save("Ayam-InceptionV3-DanielMrnth.h5")

# %%
# import glob
# import os.path
# file_test_images = glob.glob('./dataset/test/20221104_081209.jpg')

# %% [markdown]
# ## Prediksi pakai colab

# %%
# import matplotlib.image as mpimg
# import numpy as np
# from io import BytesIO
# from IPython.display import Image as IMG
# import files
# from keras.preprocessing import image
# from shutil import copyfile

# %%
# def PredGambar(file_gmbr, model = ModelDenseNet201):
#   file = file_gmbr
#   gmbr_array = np.asarray(file)
#   gmbr_array = gmbr_array*(1/225)
#   gmbr_input = tf.reshape(gmbr_array, shape = [1, 150, 150, 3])

#   predik_array = model.predict(gmbr_input)[0]

#   df = pd.DataFrame(predik_array)
#   df = df.rename({0:'NilaiKemiripan'}, axis = 'columns')
#   Kualitas = ['AyamSegar', 'AyamTiren']
#   df['Kelas'] = Kualitas
#   df = df[['Kelas', 'NilaiKemiripan']]

#   predik_kelas = np.argmax(model.predict(gmbr_input))

#   if predik_kelas == 0:
#     predik_Kualitas = 'AyamSegar'
#   else:
#     predik_Kualitas = 'AyamTiren'

#   return predik_Kualitas, df

# %%
# import keras
# import tensorflow as tf
# from tensorflow.keras.utils import load_img, img_to_array




# UnggahFile = files.upload()

# for n in UnggahFile.keys():
#   lok = n
#   gmbr = keras.utils.load_img(lok, target_size=(150,150))
#   gmbrPlot = plt.imshow(gmbr)
#   x = keras.utils.img_to_array(gmbr)
#   x = np.expand_dims(x, axis=0)
#   gmbr = np.vstack([x])

#   kelas, df = PredGambar(gmbr)

#   print('\n')
#   plt.show()
#   print("\nGambar dikenali sebagai " + kelas)
#   print('\n')
#   print(df)
#   print('\n')

# %%
# import keras
# import tensorflow as tf
# from tensorflow.keras.utils import load_img, img_to_array




# UFile = files.upload()

# for n in UFile.keys():
#   lok = n
#   gmbr = keras.utils.load_img(lok, target_size=(150,150))
#   gmbrPlot = plt.imshow(gmbr)
#   x = keras.utils.img_to_array(gmbr)
#   x = np.expand_dims(x, axis=0)
#   gmbr = np.vstack([x])

#   kelas, df = PredGambar(gmbr)

#   print('\n')
#   plt.show()
#   print("\nGambar dikenali sebagai " + kelas)
#   print('\n')
#   print(df)
#   print('\n')

# %%
# import keras
# import tensorflow as tf
# from tensorflow.keras.utils import load_img, img_to_array




# UngFile = files.upload()

# for n in UngFile.keys():
#   lok = n
#   gmbr = keras.utils.load_img(lok, target_size=(150,150))
#   gmbrPlot = plt.imshow(gmbr)
#   x = keras.utils.img_to_array(gmbr)
#   x = np.expand_dims(x, axis=0)
#   gmbr = np.vstack([x])

#   kelas, df = PredGambar(gmbr)

#   print('\n')
#   plt.show()
#   print("\nGambar dikenali sebagai " + kelas)
#   print('\n')
#   print(df)
#   print('\n')
